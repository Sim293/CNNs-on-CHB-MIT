# %% [markdown]
# <a href="https://colab.research.google.com/github/Sim293/CNNs-on-CHB-MIT/blob/master/Simone_Spectrograms_CNNs_on_CHB_MIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --no-deps git+https://github.com/dorukkarinca/keras-buoy
# Out:
# ...
#   Cloning https://github.com/dorukkarinca/keras-buoy to /tmp/pip-req-build-4v9j6250
#   Running command git clone -q https://github.com/dorukkarinca/keras-buoy /tmp/pip-req-build-4v9j6250
# ...
#   Created wheel for keras-buoy: filename=keras_buoy-0.1.4.1-py2.py3-none-any.whl size=6670 sha256=2c95a746d650689967658ce5eb70e3f78628796d83a2c493c0a42ff346ec7415
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hiu0dlrh/wheels/de/8f/5c/befe3bb1acda3f4fb9948573cb0ac67ef5150450a2f2956ee7
# Successfully built keras-buoy

# %%
# %tensorflow_version 1.x
import tensorflow as tf
# Out:
# TensorFlow 1.x selected.

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os
import pyedflib
import numpy as np

# %%
# !wget -r -N -c -np https://physionet.org/files/chbmit/1.0.0/

# %%
# !cp -r archive.physionet.org/ gdrive/MyDrive/CNNs-on-CHB-MIT/

# %%
# !git clone https://github.com/Sim293/CNNs-on-CHB-MIT.git
# Out:
# Cloning into 'CNNs-on-CHB-MIT'...
# remote: Enumerating objects: 191, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 191 (delta 87), reused 25 (delta 11), pack-reused 50
# Receiving objects: 100% (191/191), 4.35 MiB | 5.68 MiB/s, done.
# Resolving deltas: 100% (109/109), done.

# %%
# Write this into PARAMETERS_DATA_EDITING.txt
# Quando genero gli spettrogrammi
with open('CNNs-on-CHB-MIT/DataserToSpectogram.py','r') as p:
  dataser = p.read()
dataser = dataser.replace("pathDataSet=''","pathDataSet='gdrive/MyDrive/CNNs-on-CHB-MIT/archive.physionet.org/pn6/chbmit/'",1)
dataser = dataser.replace("FirstPartPathOutput=''","FirstPartPathOutput='gdrive/MyDrive/CNNs-on-CHB-MIT/spectrograms'",1)
with open('CNNs-on-CHB-MIT/DataserToSpectogram.py','w') as p:
  p.write(dataser)

# %%
# Write this into PARAMETERS_CNN.txt
# Quando devo far partire la rete
with open('CNNs-on-CHB-MIT/CNN.py','r') as c:
  cnn = c.read()
cnn = cnn.replace("PathSpectogramFolder=''","PathSpectogramFolder='gdrive/MyDrive/CNNs-on-CHB-MIT/spectrograms'",1)
cnn = cnn.replace("OutputPath=''","OutputPath='gdrive/MyDrive/CNNs-on-CHB-MIT/results/dominici/results.txt'",1)
cnn = cnn.replace("OutputPathModels=''","OutputPathModels='gdrive/MyDrive/CNNs-on-CHB-MIT/results/dominici/model/'",1)
cnn = cnn.replace("WeightsOutputPath=''","WeightsOutputPath='gdrive/MyDrive/CNNs-on-CHB-MIT/weights/dominici'",1)
with open('CNNs-on-CHB-MIT/CNN.py','w') as c:
  c.write(cnn)

# %%
# Substitute patient 19's summary with the one in the repository
# !cp CNNs-on-CHB-MIT/summaryChanged/chb19-summary.txt gdrive/MyDrive/CNNs-on-CHB-MIT/archive.physionet.org/pn6/chbmit/chb19/

# %%
# Generate the spectrograms
# !python CNNs-on-CHB-MIT/DataserToSpectogram.py

# %%
# Convert spectrograms to 2D images with 3 color channels or gray scale
import numpy as np
example_spec = np.load('gdrive/MyDrive/CNNs-on-CHB-MIT/spectrograms/paz01/spec__0_49.npy',allow_pickle=True)
# print(example_spec[0,0,0])
f = np.arange(example_spec[0,0].shape[0])
t = np.arange(example_spec[0,0].shape[1])
import matplotlib.pyplot as plt
# Plot signal
# Plot spectrogram
# plt.pcolormesh(t,f,example_spec[0,0],cmap=plt.cm.jet)
# Gray scale spectrogram
plt.pcolormesh(t,f,example_spec[0,0],cmap=plt.cm.gray)

# %%
# Generate the model and save its weights
# Remember to set GPU runtime
# %tensorflow_version 1.x
import tensorflow as tf
tf.random.set_random_seed(13216518)
! python CNNs-on-CHB-MIT/CNN.py --resume
# Out:
# START
# Parameters loaded
# Patient 02
# Spectograms data loaded
# SEIZURE OUT: 1
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Defaulting callback to earlystop...
# Training start
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# 2021-05-20 07:47:32.119604: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-05-20 07:47:32.193112: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
